# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
ballad = pd.read_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/중복데이터제거하기전(필요없는데이터)/ballad14860개.csv', encoding='utf-8', index_col=0)
dance = pd.read_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/중복데이터제거하기전(필요없는데이터)/dance15134개.csv', encoding='utf-8', index_col=0)
hiphop = pd.read_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/중복데이터제거하기전(필요없는데이터)/hiphop14325개.csv', encoding='utf-8', index_col=0)
rb = pd.read_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/중복데이터제거하기전(필요없는데이터)/rb15124개.csv', encoding='utf-8', index_col=0)
indi = pd.read_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/중복데이터제거하기전(필요없는데이터)/indi14827개.csv', encoding='utf-8', index_col=0)
rock = pd.read_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/중복데이터제거하기전(필요없는데이터)/rock13962개.csv', encoding='utf-8', index_col=0)
folk = pd.read_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/중복데이터제거하기전(필요없는데이터)/folk12872개.csv', encoding='utf-8', index_col=0)
trot = pd.read_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/중복데이터제거하기전(필요없는데이터)/trot10388개.csv', encoding='utf-8', index_col=0)

# %%
ballad = ballad.drop_duplicates(keep='first')
dance = dance.drop_duplicates(keep='first')
hiphop = hiphop.drop_duplicates(keep='first')
rb = rb.drop_duplicates(keep='first')
indi = indi.drop_duplicates(keep='first')
rock = rock.drop_duplicates(keep='first')
folk = folk.drop_duplicates(keep='first')
trot = trot.drop_duplicates(keep='first')

# %%
ballad.shape, dance.shape, hiphop.shape, rb.shape, indi.shape, rock.shape, folk.shape, trot.shape
# Out:
# ((14058, 4),
#  (14035, 4),
#  (13830, 4),
#  (14419, 4),
#  (14816, 5),
#  (13722, 5),
#  (12258, 5),
#  (10385, 5))

# %%
ballad.to_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/ballad14058.csv', encoding='utf-8')
dance.to_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/dance14035.csv', encoding='utf-8')
hiphop.to_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/hiphop13830.csv', encoding='utf-8')
rb.to_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/rb14419.csv', encoding='utf-8')
indi.to_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/indi14816.csv', encoding='utf-8')
rock.to_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/rock13722.csv', encoding='utf-8')
folk.to_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/folk12258.csv', encoding='utf-8')
trot.to_csv('/content/drive/Shareddrives/Parrot/lyrics/장르별 데이터/trot10385.csv', encoding='utf-8')

# %%
df = pd.concat([folk, rock], ignore_index=True)
df = pd.concat([df, indi], ignore_index=True)
df = pd.concat([df, rb], ignore_index=True)
df = pd.concat([df, hiphop], ignore_index=True)
df = pd.concat([df, dance], ignore_index=True)
df = pd.concat([df, ballad], ignore_index=True)
df = pd.concat([df, trot], ignore_index=True)

print(df.shape)
df
# Out:
# (107523, 5)
#                            제목  ...    장르
# 0                      오래된 노래  ...  folk
# 1                        Gone  ...  folk
# 2                         폰서트  ...  folk
# 3                     봄이 좋냐??  ...  folk
# 4                       나만, 봄  ...  folk
# ...                       ...  ...   ...
# 107518               불효자는 웁니다  ...  trot
# 107519  무조건 (DJ처리 Remix Ver.)  ...  trot
# 107520                 매정한 님아  ...  trot
# 107521                  님 그리워  ...  trot
# 107522                 들었다 놨다  ...  trot
#
# [107523 rows x 5 columns]

# %%
df.isnull().any()
# Out:
# 제목       True
# 가수      False
# 곡 번호     True
# 가사      False
# 장르      False
# dtype: bool

# %%
df['곡 번호'] = df['곡 번호'].fillna('0')
df['곡 번호'] = df['곡 번호'].astype(int)
df
# Out:
#                            제목  ...    장르
# 0                      오래된 노래  ...  folk
# 1                        Gone  ...  folk
# 2                         폰서트  ...  folk
# 3                     봄이 좋냐??  ...  folk
# 4                       나만, 봄  ...  folk
# ...                       ...  ...   ...
# 107518               불효자는 웁니다  ...  trot
# 107519  무조건 (DJ처리 Remix Ver.)  ...  trot
# 107520                 매정한 님아  ...  trot
# 107521                  님 그리워  ...  trot
# 107522                 들었다 놨다  ...  trot
#
# [107523 rows x 5 columns]

# %%
df.isnull().any()
# Out:
# 제목       True
# 가수      False
# 곡 번호    False
# 가사      False
# 장르      False
# dtype: bool

# %%
df[df['제목'].isnull()]
# Out:
#         제목  가수  ...                                                 가사        장르
# 44054  NaN  주영  ...  늘 그랬듯 쉬운 건\n하나 없어 거울 앞에 난\nTrying to wave at h...  R&B/Soul
#
# [1 rows x 5 columns]

# %%
df.iloc[44054,0] = '제목 N/A'
df.iloc[44054:44055]
# Out:
#            제목  가수  ...                                                 가사        장르
# 44054  제목 N/A  주영  ...  늘 그랬듯 쉬운 건\n하나 없어 거울 앞에 난\nTrying to wave at h...  R&B/Soul
#
# [1 rows x 5 columns]

# %%
df.isnull().any()
# Out:
# 제목      False
# 가수      False
# 곡 번호    False
# 가사      False
# 장르      False
# dtype: bool

# %%
df = df.loc[df['가사'] != '\n']

# %%
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                                                        제목  ...        장르
# 0                                             너에게로 떠나는 여행  ...      rock
# 1       DNA (Youth Remix) (Feat. 조원우, Rohann, HAON & 이영지)  ...    hiphop
# 2                                                 아름다운 강산  ...      rock
# 3                                             Let's Dance  ...     dance
# 4                                                   대전부르스  ...      trot
# ...                                                   ...  ...       ...
# 107518                                                 정릉  ...      indi
# 107519                                           찬비 내리는 밤  ...      folk
# 107520                                      Pumpkin Heart  ...      folk
# 107521                                       공백 (feat.소언)  ...  R&B/Soul
# 107522                                              피 (避)  ...  R&B/Soul
#
# [107523 rows x 5 columns]

# %%
df.to_csv('/content/drive/Shareddrives/Parrot/lyrics/107486곡.csv', encoding='utf-8')
