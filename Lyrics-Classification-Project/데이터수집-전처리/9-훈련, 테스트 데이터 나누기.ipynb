# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/Shareddrives/Parrot/data.csv', encoding='utf-8', index_col=0)
df
# Out:
#                                           제목            가수     곡 번호  ...  락 트로트  포크
# 0                                  일어나 (김광석)           장철웅  1824386  ...  0   0   1
# 1                           바람이 불어오는 곳 (김광석)           장철웅  1824389  ...  0   0   1
# 2                                      그 사나이      함중아와 양키스    64092  ...  1   0   0
# 3                                      고향 바다           박인희    48219  ...  0   0   1
# 4                                     그리운 얼굴           김종환  1877137  ...  0   1   0
# ...                                      ...           ...      ...  ... ..  ..  ..
# 97689                               단 한번의 사랑  The One (더원)        0  ...  0   0   0
# 97690                  최고의 선물 (Prod. by PSY)             비        0  ...  0   0   0
# 97691                                     제발           박강수        0  ...  0   0   0
# 97692                          Got Your Back  비오브유 (B.O.Y)        0  ...  0   0   0
# ...

# %%
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                                    제목                가수     곡 번호  ...  락 트로트  포크
# 0                              新 사랑고개               금잔디  3979593  ...  0   1   0
# 1                                 달리자              빡구동구  4177726  ...  0   1   0
# 2                                유리구두               금잔디  4079497  ...  0   1   0
# 3                               Bloom             GONOK        0  ...  0   0   0
# 4                      Christmalo.win               서태지  5414970  ...  1   0   0
# ...                               ...               ...      ...  ... ..  ..  ..
# 97689                      in love <3  Gpicking, TAKUWA        0  ...  0   0   0
# 97690                    있잖아, 널 좋아하나봐               강시온  5520807  ...  0   0   1
# 97691      Who Are U (Feat. Superbee)         라비 (RAVI)        0  ...  0   0   0
# 97692  no new friends (Prod. By Nuol)       올티 (Olltii)        0  ...  0   0   0
# 97693                             리베카          태호 (임팩트)        0  ...  0   0   0
#
# ...

# %%
test = df.iloc[:10000]
test
# Out:
#                                  제목      가수      곡 번호  ...  락 트로트  포크
# 0                            新 사랑고개     금잔디   3979593  ...  0   1   0
# 1                               달리자    빡구동구   4177726  ...  0   1   0
# 2                              유리구두     금잔디   4079497  ...  0   1   0
# 3                             Bloom   GONOK         0  ...  0   0   0
# 4                    Christmalo.win     서태지   5414970  ...  1   0   0
# ...                             ...     ...       ...  ... ..  ..  ..
# 9995                         존재의 이유    이츠허밍  31674381  ...  0   0   1
# 9996                         가난한 마음     양희은  30649371  ...  0   0   1
# 9997                       갑돌이와 갑순이     최숙자  32861925  ...  0   1   0
# 9998  City Girl City Boy (Feat. 다원)  서교동의 밤  31258251  ...  0   0   0
# 9999  레디 큐 (Ready Q) (Remix by 유스타)     조정민  31757818  ...  0   1   0
#
# [10000 rows x 13 columns]

# %%
test.to_csv('/content/drive/Shareddrives/Parrot/test/test.csv',encoding='utf-8')

# %%
train = df.iloc[10000:].reset_index(drop=True)
train
# Out:
#                                     제목                가수      곡 번호  ...  락 트로트  포크
# 0                  Maybe (Remember Me)               은지원         0  ...  0   0   0
# 1                                  정거장               김수희     50420  ...  0   1   0
# 2      SHIO YAKISOBA (Feat. BIL (김상빈))       디핵 (D-Hack)         0  ...  0   0   0
# 3                              내 방은 궁전               정밀아   5437361  ...  0   0   1
# 4        TOM FORD (Feat. Rakon, 크루셜스타)             Choic  33225390  ...  0   0   0
# ...                                ...               ...       ...  ... ..  ..  ..
# 87689                       in love <3  Gpicking, TAKUWA         0  ...  0   0   0
# 87690                     있잖아, 널 좋아하나봐               강시온   5520807  ...  0   0   1
# 87691       Who Are U (Feat. Superbee)         라비 (RAVI)         0  ...  0   0   0
# 87692   no new friends (Prod. By Nuol)       올티 (Olltii)         0  ...  0   0   0
# ...

# %%
train.to_csv('/content/drive/Shareddrives/Parrot/train/train.csv',encoding='utf-8')
